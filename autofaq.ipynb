# %%
# !pip install requests scikit-learn requests

# %%
from sdk import Client, QnaAPI
from sklearn.metrics import classification_report, accuracy_score, f1_score
from json import dump
import time
import numpy as np

# %%
def parse_data(path):
    X = []
    y = []
    docs = {}
    with open(path, 'r') as f:
        for line in f:
            splitted = line.split(',')
            label = splitted[0]
            sent = ", ".join(splitted[2:]).strip()
            X.append(sent)
            y.append(label) 
            if label not in docs:
                docs[label] = {'question': sent, 'answer': label, 'name': label, 'paraphrased_questions': []}
            else:
                docs[label]['paraphrased_questions'].append(sent)
    return docs, X, y

# %%
host_url = 'https://chat.autofaq.ai'
namespace = 'core-api/crud/api/v1'
api_url = 'https://chat.autofaq.ai/core-api/query'


small_test_path = 'data/hwu_small_test.csv'
small_train_path = 'data/hwu_small_train.csv'

large_test_path = 'data/hwu_large_test.csv'
large_train_path = 'data/hwu_large_train.csv'

# %%
# Contact info@autofaq.ai to get user_id and user_token
user_id = 1
user_token = 'xx'

# %%
def hwu_metrics_calc(test_path, train_path, user_id, user_token, name, namespace):
    docs_test, X_test, y_test = parse_data(test_path)
    docs_train, _, _ = parse_data(train_path)
    print("Parsed data")
    
    client = Client(host_url=host_url, user_id=user_id, user_token=user_token, namespace=namespace)
    Client.HTTP_TIMEOUT = 180

    service_response = client.create_service({'preset': 'en', 'name': name})
    for doc in docs_train.values():
        client.create_document(
            service_response['service_id'], 
            question=doc['question'], 
            answer=doc['answer'], 
            name=doc['name'], 
            paraphrases=doc['paraphrased_questions']
        )
    
    client.publish_service(service_response['service_id'], wait_timeout=180)
    print("Service published")

    qna = QnaAPI(api_url, service_response['service_id'], service_response['tokens'][0])

    print("Querying API ...")
    test_results = []
    times = []
    for row in X_test:
        start_time = time.time()
        res = qna.query(row)
        times.append(time.time() - start_time)
        test_results.append(res)

    y_pred = []
    for r in test_results:
        y_pred.append(r['results'][0]['name'])
    print(classification_report(y_test, y_pred))
    print("Accuracy: ", accuracy_score(y_test, y_pred)) 
    print("F1-Score: ", f1_score(y_test, y_pred, average='macro'))   
    print(f"Mean response time: {np.mean(times)} +- {np.std(times)} sec.")

# %%
hwu_metrics_calc(small_test_path, small_train_path, user_id, user_token, 'HWU-Small', namespace)
# Out:
# Parsed data
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# Service published
# Querying API ...
#                           precision    recall  f1-score   support
#
#              alarm_query       0.94      0.89      0.92        19
#             alarm_remove       0.60      0.82      0.69        11
#                alarm_set       0.71      0.79      0.75        19
#        audio_volume_down       0.64      0.88      0.74         8
#        audio_volume_mute       0.55      0.40      0.46        15
#          audio_volume_up       0.62      0.77      0.69        13
#           calendar_query       0.37      0.58      0.45        19
#          calendar_remove       1.00      0.89      0.94        19
#             calendar_set       0.82      0.47      0.60        19
#           cooking_recipe       0.89      0.89      0.89        19
#         datetime_convert       0.78      0.88      0.82         8
#           datetime_query       0.73      0.84      0.78        19
#         email_addcontact       0.64      0.88      0.74         8
#              email_query       1.00      0.95      0.97        19
#       email_querycontact       0.86      0.63      0.73        19
#          email_sendemail       0.84      0.84      0.84        19
#           general_affirm       0.95      1.00      0.97        19
#      general_commandstop       0.90      0.95      0.92        19
#          general_confirm       0.95      1.00      0.97        19
#         general_dontcare       0.86      0.95      0.90        19
#          general_explain       0.89      0.89      0.89        19
#             general_joke       1.00      1.00      1.00        12
#           general_negate       0.77      0.89      0.83        19
#           general_praise       0.95      0.95      0.95        19
#           general_quirky       0.80      0.21      0.33        19
#           general_repeat       1.00      0.84      0.91        19
#             iot_cleaning       1.00      1.00      1.00        16
#               iot_coffee       0.95      1.00      0.97        19
#      iot_hue_lightchange       0.82      0.74      0.78        19
#         iot_hue_lightdim       0.86      1.00      0.92        12
#         iot_hue_lightoff       0.71      0.79      0.75        19
#          iot_hue_lighton       0.11      0.33      0.17         3
#          iot_hue_lightup       0.86      0.43      0.57        14
#             iot_wemo_off       0.80      0.89      0.84         9
#              iot_wemo_on       0.67      0.57      0.62         7
#        lists_createoradd       0.62      0.68      0.65        19
#              lists_query       0.73      0.58      0.65        19
#             lists_remove       1.00      0.79      0.88        19
#           music_likeness       0.89      0.89      0.89        18
#              music_query       0.71      0.63      0.67        19
#           music_settings       0.43      0.43      0.43         7
#               news_query       0.93      0.68      0.79        19
#           play_audiobook       0.72      0.68      0.70        19
#                play_game       0.74      0.89      0.81        19
#               play_music       0.52      0.58      0.55        19
#            play_podcasts       0.77      0.89      0.83        19
#               play_radio       0.93      0.74      0.82        19
#              qa_currency       0.89      0.89      0.89        19
#            qa_definition       0.89      0.84      0.86        19
#               qa_factoid       0.43      0.53      0.48        19
#                 qa_maths       0.87      0.93      0.90        14
#                 qa_stock       0.79      1.00      0.88        19
#    recommendation_events       0.81      0.68      0.74        19
# recommendation_locations       0.90      0.95      0.92        19
#    recommendation_movies       0.75      0.90      0.82        10
#              social_post       0.85      0.89      0.87        19
#             social_query       0.88      0.83      0.86        18
#           takeaway_order       0.70      0.84      0.76        19
#           takeaway_query       1.00      0.58      0.73        19
#          transport_query       0.89      0.84      0.86        19
#           transport_taxi       0.90      1.00      0.95        18
#         transport_ticket       0.95      0.95      0.95        19
#        transport_traffic       0.90      0.95      0.92        19
#            weather_query       0.95      0.95      0.95        19
#
#                 accuracy                           0.80      1076
#                macro avg       0.80      0.79      0.79      1076
#             weighted avg       0.82      0.80      0.80      1076
#
# Accuracy:  0.8029739776951673
# F1-Score:  0.7867666426805067

# %%
hwu_metrics_calc(large_test_path, large_train_path, user_id, user_token, 'HWU-Large', namespace)
# Out:
# Parsed data
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# publish_service wait ..
# Service published
# Querying API ...
#                           precision    recall  f1-score   support
#
#              alarm_query       0.95      0.89      0.92        94
#             alarm_remove       0.84      0.91      0.88        54
#                alarm_set       0.85      0.85      0.85        96
#        audio_volume_down       0.70      0.80      0.74        40
#        audio_volume_mute       0.86      0.84      0.85        76
#          audio_volume_up       0.86      0.75      0.80        73
#           calendar_query       0.65      0.67      0.66        95
#          calendar_remove       0.86      0.87      0.87       102
#             calendar_set       0.68      0.80      0.74        91
#           cooking_recipe       0.92      0.91      0.92       107
#         datetime_convert       0.82      0.89      0.86        47
#           datetime_query       0.85      0.87      0.86        92
#         email_addcontact       0.82      0.95      0.88        38
#              email_query       0.90      0.90      0.90        93
#       email_querycontact       0.85      0.78      0.82       105
#          email_sendemail       0.91      0.86      0.89        94
#           general_affirm       0.98      0.81      0.88        98
#      general_commandstop       0.94      0.98      0.96        94
#          general_confirm       0.95      1.00      0.98        84
#         general_dontcare       0.98      1.00      0.99       100
#          general_explain       0.97      0.92      0.94        99
#             general_joke       0.98      0.95      0.96        58
#           general_negate       0.85      0.92      0.89        93
#           general_praise       0.83      1.00      0.91        96
#           general_quirky       0.35      0.33      0.34       104
#           general_repeat       0.96      0.97      0.97       100
#             iot_cleaning       0.96      0.94      0.95        82
#               iot_coffee       0.98      0.99      0.98        98
#      iot_hue_lightchange       0.95      0.88      0.91       102
#         iot_hue_lightdim       0.79      0.89      0.84        56
#         iot_hue_lightoff       0.93      0.87      0.90        98
#          iot_hue_lighton       0.41      0.47      0.44        19
#          iot_hue_lightup       0.78      0.81      0.79        74
#             iot_wemo_off       0.92      0.89      0.90        53
#              iot_wemo_on       0.77      0.88      0.82        41
#        lists_createoradd       0.89      0.79      0.84        94
#              lists_query       0.81      0.85      0.83        99
#             lists_remove       0.99      0.87      0.93       108
#           music_likeness       0.93      0.86      0.89        93
#              music_query       0.90      0.82      0.86       100
#           music_settings       0.65      0.82      0.73        34
#               news_query       0.84      0.71      0.77        94
#           play_audiobook       0.82      0.88      0.85        96
#                play_game       0.86      0.90      0.88       100
#               play_music       0.75      0.70      0.72        97
#            play_podcasts       0.90      0.90      0.90        93
#               play_radio       0.86      0.87      0.86        89
#              qa_currency       0.95      0.98      0.96        92
#            qa_definition       0.87      0.85      0.86        97
#               qa_factoid       0.71      0.64      0.67        85
#                 qa_maths       0.85      0.92      0.88        75
#                 qa_stock       0.93      0.94      0.94       104
#    recommendation_events       0.73      0.81      0.77        85
# recommendation_locations       0.80      0.81      0.80        84
#    recommendation_movies       0.89      0.90      0.90        63
#              social_post       0.90      0.86      0.88        98
#             social_query       0.84      0.82      0.83        93
#           takeaway_order       0.79      0.83      0.81       101
#           takeaway_query       0.81      0.75      0.78       103
#          transport_query       0.83      0.83      0.83       104
#           transport_taxi       0.91      0.96      0.94        84
#         transport_ticket       0.90      0.93      0.92       107
#        transport_traffic       0.95      0.91      0.92        95
#            weather_query       0.90      0.99      0.95       105
#
#                 accuracy                           0.86      5518
#                macro avg       0.85      0.86      0.85      5518
#             weighted avg       0.86      0.86      0.86      5518
#
# Accuracy:  0.8582819862268938
# F1-Score:  0.851143182658985
# Mean response time: 0.2700873253439682 +- 0.03548288426912708 sec.
